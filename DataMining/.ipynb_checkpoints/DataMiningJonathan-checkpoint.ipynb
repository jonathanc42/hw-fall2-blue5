# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('FFTSales.csv')

# %% [markdown]
# # EDA

# %% [markdown]
# ## Graphic Interperation

# %%
df2 = df.groupby(['ConsumerGroup', 'y'])['ConsumerGroup'].count().unstack('y')
df2[['yes','no']].plot(kind='bar', stacked=True)

# %%
df2.plot.pie(subplots=True, figsize=(8, 4))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1120967f0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1120d3668>],
#       dtype=object)

# %%
df3 = df.groupby(['y','ConsumerGroup'])['y'].count().unstack('ConsumerGroup')
df3[['A','B','C','D']].plot(kind='bar', stacked=True)

# %%
df3.plot.pie(subplots=True,figsize=(16, 4))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1140c6f98>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1021d32b0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1034d2828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1021f9da0>],
#       dtype=object)

# %%
import matplotlib.ticker as mtick

# %%
df4=df
df4.ConsumerGroup=df4.ConsumerGroup.apply(lambda x:'A,C,D' if x != 'B' else 'B')

# %%
df4 = df4.groupby(['y','ConsumerGroup'])['y'].count().unstack('ConsumerGroup')

# %%
#3e9818 
#c72f3d

# %%
from matplotlib.ticker import FuncFormatter
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 6))
df4[['B','A,C,D']].plot(kind='bar', stacked=True,
                        width=.5, edgecolor='white',color=[['#3e9818','#c72f3d'],['#3e9818','#c72f3d']],
                       ax=ax)
plt.title('FFT subscriptions by Consumer Groups',size=25)

def thousandk(x, pos):
    'The two args are the value and tick position'
    return '%1.fK' % (x/1000)

formatter = FuncFormatter(thousandk)

ax.yaxis.set_major_formatter(formatter)

plt.xticks(rotation='horizontal')
plt.xlabel('subscription',size=15)
plt.ylabel('frequency',size=15)
plt.savefig('subscriptions by Consumer Groups.png')
#plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 6))
df4[['B','A,C,D']].plot(kind='bar', stacked=True,
                        width=.5, edgecolor='white',
                       ax=ax)
plt.title('FFT subscriptions by Consumer Groups',size=25)

def thousandk(x, pos):
    'The two args are the value and tick position'
    return '%1.fK' % (x/1000)

formatter = FuncFormatter(thousandk)

ax.yaxis.set_major_formatter(formatter)

plt.xticks(rotation='horizontal')
plt.xlabel('subscription',size=15)
plt.ylabel('frequency',size=15)
plt.savefig('subscriptions by Consumer Groups.png')
#plt.show()

# %%
x = np.arange(4)
money = [1.5e5, 2.5e6, 5.5e6, 2.0e7]


def millions(x, pos):
    'The two args are the value and tick position'
    return '$%1.1fM' % (x*1e-6)

formatter = FuncFormatter(millions)

fig, ax = plt.subplots()
ax.yaxis.set_major_formatter(formatter)
plt.bar(x, money)
plt.xticks(x, ('Bill', 'Fred', 'Mary', 'Sue'))
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


df = pd.DataFrame({'A': ['A', 'B'], 'B': [1000,2000]})

fig, ax = plt.subplots(1, 1, figsize=(2, 2))
df.plot(kind='bar', x='A', y='B',
        align='center', width=.5, edgecolor='none', 
        color='grey', ax=ax)

fmt = '${x:,.0f}'
tick = mtick.StrMethodFormatter(fmt)
ax.yaxis.set_major_formatter(tick) 
plt.xticks(rotation=25)

plt.show()

# %%
df[df.total_contacts!=0].total_contacts.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-39e7f58b6a09> in <module>()
# ----> 1 df[df.total_contacts!=0].total_contacts.describe()
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'total_contacts'

# %%
df.head()
# Out:
#    age           job  education default  balance loan  day month   y  \
# 0   58    management   tertiary      no   410192   no    5   may  no
# 1   44    technician  secondary      no   753784   no    5   may  no
# 2   33  entrepreneur  secondary      no   487820  yes    5   may  no
# 3   47   blue-collar    unknown      no   206021   no    5   may  no
# 4   33       unknown    unknown      no   599481   no    5   may  no
#
#   val_email phone_type ConsumerGroup  contacts  days_since  total_contacts  \
# 0        no    unknown             A         1          -1               0
# 1        no    unknown             A         1          -1               0
# 2        no    unknown             B         1          -1               0
# 3        no    unknown             B         1          -1               0
# 4        no    unknown             A         1          -1               0
#
#   last_campaign_outcome mortgage
# 0               unknown      yes
# 1               unknown      yes
# 2               unknown      yes
# 3               unknown      yes
# 4               unknown       no

# %%
df.describe()
# Out:
#                  B
# count     2.000000
# mean   1500.000000
# std     707.106781
# min    1000.000000
# 25%    1250.000000
# 50%    1500.000000
# 75%    1750.000000
# max    2000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
# A    2 non-null object
# B    2 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 112.0+ bytes

# %%
df.groupby(['job','y']).mean()
# Out:
#         B
# job  1000
# y    2000

# %%
df.groupby(['job','y']).size().plot(kind='bar')

# %%
test=(df[df.y=='yes'].groupby(['job', 'y']).size()/
      df.groupby(['job']).size()).reset_index().rename(columns={0: 'rate'}).\
        drop('y',axis=1).sort_values('rate',ascending=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-dca035395b83> in <module>()
# ----> 1 test=(df[df.y=='yes'].groupby(['job', 'y']).size()/
#       2       df.groupby(['job']).size()).reset_index().rename(columns={0: 'rate'}).\
#       3         drop('y',axis=1).sort_values('rate',ascending=False)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'y'

# %%
test.plot(x='job',y='rate',kind='bar',color='c')
plt.ylabel('Yes Rate')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-4a1c27c77027> in <module>()
# ----> 1 test.plot(x='job',y='rate',kind='bar',color='c')
#       2 plt.ylabel('Yes Rate')
#
# NameError: name 'test' is not defined

# %%
who
# Out:
# FuncFormatter	 ax	 df	 df2	 df3	 df4	 fig	 fmt	 formatter
# json	 lib2to3	 millions	 money	 mtick	 np	 pd	 plt	 thousandk
# tick	 x

# %%
df.ConsumerGroup.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-08a2c6f94746> in <module>()
# ----> 1 df.ConsumerGroup.describe()
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'ConsumerGroup'

# %% [markdown]
# # Decision Tree

# %%
from sklearn import tree
from sklearn.datasets import load_iris
import graphviz
from sklearn import preprocessing

# %% [markdown]
# ## Model Fitting

# %%
dt=tree.DecisionTreeClassifier(max_depth=5, max_leaf_nodes=10,
                               max_features=None,
                               min_samples_leaf=3000,
                               min_samples_split=2,
                               presort=False, splitter='best',
                               criterion='entropy',random_state=42)

# %%
dt=tree.DecisionTreeClassifier(max_depth=5, max_leaf_nodes=10,
                               min_samples_leaf=3000,
                               min_impurity_split=1e-07,
                               criterion='entropy',random_state=42424242)

# %%
encoded_df=df

# %%
for column in encoded_df.columns:
    if encoded_df[column].dtype == type(object):
        le = preprocessing.LabelEncoder()
        encoded_df[column] = le.fit_transform(encoded_df[column])

# %%
df.columns
# Out:
# Index(['age', 'job', 'education', 'default', 'balance', 'loan', 'day', 'month',
#        'y', 'val_email', 'phone_type', 'ConsumerGroup', 'contacts',
#        'days_since', 'total_contacts', 'last_campaign_outcome', 'mortgage'],
#       dtype='object')

# %%
X_train=encoded_df.drop('y',axis=1)

# %%
dt.fit(X_train,encoded_df.y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features=None, max_leaf_nodes=10,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=3000, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')

# %%
encoded_df.head()
# Out:
#    age  job  education  default  balance  loan  day  month  y  val_email  \
# 0   58    4          2        0   410192     0    5      8  0          0
# 1   44    9          1        0   753784     0    5      8  0          0
# 2   33    2          1        0   487820     1    5      8  0          0
# 3   47    1          3        0   206021     0    5      8  0          0
# 4   33   11          3        0   599481     0    5      8  0          0
#
#    phone_type  ConsumerGroup  contacts  days_since  total_contacts  \
# 0           2              0         1          -1               0
# 1           2              0         1          -1               0
# 2           2              1         1          -1               0
# 3           2              1         1          -1               0
# 4           2              0         1          -1               0
#
#    last_campaign_outcome  mortgage
# 0                      3         1
# 1                      3         1
# 2                      3         1
# 3                      3         1
# 4                      3         0

# %%
dot_data = tree.export_graphviz(dt, out_file=None) 
graph = graphviz.Source(dot_data) 
graph.render("dt_tree")
# Out:
# 'dt_tree.pdf'

# %%
dot_data = tree.export_graphviz(dt, out_file=None, 
                         feature_names=X_train.columns,
                                class_names=['No','Yes'],
                         filled=True, rounded=True,  
                         special_characters=True)  
graph = graphviz.Source(dot_data)  
graph
