# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('FFTSales.csv')

# %% [markdown]
# # EDA

# %% [markdown]
# ## Graphic Interperation

# %%
df2 = df.groupby(['ConsumerGroup', 'y'])['ConsumerGroup'].count().unstack('y')
df2[['yes','no']].plot(kind='bar', stacked=True)

# %%
df2.plot.pie(subplots=True, figsize=(8, 4))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x121fb1278>,
# ...
#       dtype=object)

# %%
df3 = df.groupby(['y','ConsumerGroup'])['y'].count().unstack('ConsumerGroup')
df3[['A','B','C','D']].plot(kind='bar', stacked=True)

# %%
df3.plot.pie(subplots=True,figsize=(16, 4))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x122311ba8>,
# ...
#       dtype=object)

# %%
import matplotlib.ticker as mtick

# %%
df4=df
df4.ConsumerGroup=df4.ConsumerGroup.apply(lambda x:'A,C,D' if x != 'B' else 'B')

# %%
df4 = df4.groupby(['y','ConsumerGroup'])['y'].count().unstack('ConsumerGroup')

# %%
#3e9818 
#c72f3d

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 6))
df4[['B','A,C,D']].plot(kind='bar', stacked=True,
                        width=.5, edgecolor='white',color=[['#3e9818','#c72f3d'],['#3e9818','#c72f3d']],
                       ax=ax)
plt.title('FFT subscriptions by Consumer Groups',size=25)

def thousandk(x, pos):
    'The two args are the value and tick position'
    return '%1.fK' % (x/1000)

formatter = FuncFormatter(thousandk)

ax.yaxis.set_major_formatter(formatter)

plt.xticks(rotation='horizontal')
plt.xlabel('subscription',size=15)
plt.ylabel('frequency',size=15)
plt.savefig('subscriptions by Consumer Groups.png')
#plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 6))
df4[['B','A,C,D']].plot(kind='bar', stacked=True,
                        width=.5, edgecolor='white',
                       ax=ax)
plt.title('FFT subscriptions by Consumer Groups',size=25)

def thousandk(x, pos):
    'The two args are the value and tick position'
    return '%1.fK' % (x/1000)

formatter = FuncFormatter(thousandk)

ax.yaxis.set_major_formatter(formatter)

plt.xticks(rotation='horizontal')
plt.xlabel('subscription',size=15)
plt.ylabel('frequency',size=15)
plt.savefig('subscriptions by Consumer Groups.png')
#plt.show()

# %%
from matplotlib.ticker import FuncFormatter
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(4)
money = [1.5e5, 2.5e6, 5.5e6, 2.0e7]


def millions(x, pos):
    'The two args are the value and tick position'
    return '$%1.1fM' % (x*1e-6)

formatter = FuncFormatter(millions)

fig, ax = plt.subplots()
ax.yaxis.set_major_formatter(formatter)
plt.bar(x, money)
plt.xticks(x, ('Bill', 'Fred', 'Mary', 'Sue'))
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


df = pd.DataFrame({'A': ['A', 'B'], 'B': [1000,2000]})

fig, ax = plt.subplots(1, 1, figsize=(2, 2))
df.plot(kind='bar', x='A', y='B',
        align='center', width=.5, edgecolor='none', 
        color='grey', ax=ax)

fmt = '${x:,.0f}'
tick = mtick.StrMethodFormatter(fmt)
ax.yaxis.set_major_formatter(tick) 
plt.xticks(rotation=25)

plt.show()

# %%
df[df.total_contacts!=0].total_contacts.describe()
# Out:
# count    8257.000000
# mean        3.177546
# std         4.560820
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         4.000000
# max       275.000000
# Name: total_contacts, dtype: float64

# %%
df.contacts.describe()
# Out:
# count    45211.000000
# mean         2.763841
# std          3.098021
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         63.000000
# Name: contacts, dtype: float64

# %%
df.head()
# Out:
#    age           job  education default  balance loan  day month   y  \
# 0   58    management   tertiary      no   410192   no    5   may  no
# 1   44    technician  secondary      no   753784   no    5   may  no
# 2   33  entrepreneur  secondary      no   487820  yes    5   may  no
# 3   47   blue-collar    unknown      no   206021   no    5   may  no
# 4   33       unknown    unknown      no   599481   no    5   may  no
#
#   val_email phone_type ConsumerGroup  contacts  days_since  total_contacts  \
# 0        no    unknown             A         1          -1               0
# 1        no    unknown             A         1          -1               0
# 2        no    unknown             B         1          -1               0
# 3        no    unknown             B         1          -1               0
# 4        no    unknown             A         1          -1               0
#
#   last_campaign_outcome mortgage
# 0               unknown      yes
# ...

# %%
df.describe()
# Out:
#                 age       balance           day      contacts    days_since  \
# count  45211.000000  4.521100e+04  45211.000000  45211.000000  45211.000000
# mean      40.936210  5.836841e+05     15.806419      2.763841     40.197828
# std       10.618762  2.888004e+05      8.322476      3.098021    100.128746
# min       18.000000  0.000000e+00      1.000000      1.000000     -1.000000
# 25%       33.000000  3.870085e+05      8.000000      1.000000     -1.000000
# 50%       39.000000  5.738750e+05     16.000000      2.000000     -1.000000
# 75%       48.000000  7.651725e+05     21.000000      3.000000     -1.000000
# max       95.000000  2.189747e+06     31.000000     63.000000    871.000000
#
#        total_contacts
# count    45211.000000
# mean         0.580323
# std          2.303441
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max        275.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
# age                      45211 non-null int64
# job                      45211 non-null object
# education                45211 non-null object
# default                  45211 non-null object
# balance                  45211 non-null int64
# loan                     45211 non-null object
# day                      45211 non-null int64
# month                    45211 non-null object
# y                        45211 non-null object
# val_email                45211 non-null object
# phone_type               45211 non-null object
# ConsumerGroup            45211 non-null object
# contacts                 45211 non-null int64
# days_since               45211 non-null int64
# total_contacts           45211 non-null int64
# last_campaign_outcome    45211 non-null object
# mortgage                 45211 non-null object
# dtypes: int64(6), object(11)
# memory usage: 5.9+ MB

# %%
df.y.describe()
# Out:
# count     45211
# unique        2
# top          no
# freq      33957
# Name: y, dtype: object

# %%
df.job.describe()
# Out:
# count           45211
# unique             12
# top       blue-collar
# freq             9732
# Name: job, dtype: object

# %%
df.groupby(['job','y']).mean()
# Out:
#                          age        balance        day  contacts  days_since  \
# job           y
# admin.        no   39.294194  547351.638710  15.629161  2.679484   44.312000
#               yes  39.277006  688819.754630  15.370370  2.263889   58.464506
# blue-collar   no   40.175487  547330.427414  15.382203  2.827257   42.949562
#               yes  39.560366  681355.458874  15.664743  2.779221   48.023569
# entrepreneur  no   42.294915  562446.724576  15.829661  2.795763   30.767797
#               yes  41.791531  655119.648208  15.211726  2.814332   39.091205
# housemaid     no   46.083588  551211.356779  16.043833  2.810398   17.673802
#               yes  47.671815  682907.814672  15.845560  2.861004   36.019305
# management    no   40.544173  555275.609784  16.321727  2.940576   32.640288
#               yes  40.187400  679189.990829  15.539075  2.653110   55.362041
# retired       no   59.932111  559959.476578  15.355058  2.507807   29.579769
# ...

# %%
df.groupby(['job','y']).size().plot(kind='bar')

# %%
test=(df[df.y=='yes'].groupby(['job', 'y']).size()/
      df.groupby(['job']).size()).reset_index().rename(columns={0: 'rate'}).\
        drop('y',axis=1).sort_values('rate',ascending=False)

# %%
test.plot(x='job',y='rate',kind='bar',color='c')
plt.ylabel('Yes Rate')
# Out:
# Text(0,0.5,'Yes Rate')

# %%
who
# Out:
# df	 json	 lib2to3	 pd	 plt	 test

# %%
df.ConsumerGroup.describe()
# Out:
# count     45211
# unique        4
# top           A
# freq      26778
# Name: ConsumerGroup, dtype: object

# %% [markdown]
# # Decision Tree

# %%
from sklearn import tree
from sklearn.datasets import load_iris
import graphviz
from sklearn import preprocessing

# %% [markdown]
# ## Model Fitting

# %%
dt=tree.DecisionTreeClassifier(max_depth=5, max_leaf_nodes=10,
                               min_samples_leaf=3000,
                               criterion='entropy',random_state=42424242)

# %%
encoded_df=df

# %%
for column in encoded_df.columns:
    if encoded_df[column].dtype == type(object):
        le = preprocessing.LabelEncoder()
        encoded_df[column] = le.fit_transform(encoded_df[column])

# %%
X_train=encoded_df.drop('y',axis=1)

# %%
dt.fit(X_train,encoded_df.y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features=None, max_leaf_nodes=10,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=3000, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False,
#             random_state=42424242, splitter='best')

# %%
encoded_df.head()
# Out:
#    age  job  education  default  balance  loan  day  month  y  val_email  \
# 0   58    4          2        0   410192     0    5      8  0          0
# 1   44    9          1        0   753784     0    5      8  0          0
# 2   33    2          1        0   487820     1    5      8  0          0
# 3   47    1          3        0   206021     0    5      8  0          0
# 4   33   11          3        0   599481     0    5      8  0          0
#
#    phone_type  ConsumerGroup  contacts  days_since  total_contacts  \
# 0           2              0         1          -1               0
# 1           2              0         1          -1               0
# 2           2              1         1          -1               0
# 3           2              1         1          -1               0
# 4           2              0         1          -1               0
#
#    last_campaign_outcome  mortgage
# 0                      3         1
# 1                      3         1
# ...

# %%
dot_data = tree.export_graphviz(dt, out_file=None) 
graph = graphviz.Source(dot_data) 
graph.render("dt_tree")
# Out:
# 'dt_tree.pdf'

# %%
dot_data = tree.export_graphviz(dt, out_file=None, 
                         feature_names=X_train.columns,
                                class_names=['Yes','No'],
                         filled=True, rounded=True,  
                         special_characters=True)  
graph = graphviz.Source(dot_data)  
graph
